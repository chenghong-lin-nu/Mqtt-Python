# %%
# read codes and labels from file
import csv
import numpy as np

with open('labels') as f:
    reader = csv.reader(f, delimiter='\n')
    labels = np.array([each for each in reader if len(each) > 0]).squeeze()
with open('codes') as f:
    codes = np.fromfile(f, dtype=np.float32)
    codes = codes.reshape((len(labels), -1))

# %%
from sklearn.preprocessing import LabelBinarizer

lb = LabelBinarizer()
lb.fit(labels)

labels_vecs = lb.transform(labels)

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
from scipy.ndimage import imread
import tensorflow as tf
from skimage import io

# %%
img_src = "https://face--recognition.oss-cn-shanghai.aliyuncs.com/baby1.jpg"
image = io.imread(img_src)
io.imshow(image)
io.show()
# Out:
# D:\Anaconda\envs\dlnd\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
print(image.shape)
# Out:
# (85, 85, 3)

# %% [markdown]
# ## 这样就可以判断是否模型已经导入，就不用每次都导入了！

# %%
import os

import numpy as np
import tensorflow as tf

from tensorflow_vgg import vgg16
from tensorflow_vgg import utils

img = utils.load_image(img_src)
img = img.reshape((1, 224, 224, 3))


try:
    feed_dict = {input_: img}
    code = sess.run(vgg.relu6, feed_dict=feed_dict)
    
    inputs_ = graph.get_tensor_by_name('inputs:0')
    predicted = graph.get_tensor_by_name('op_predicted:0')
except:
    tf.reset_default_graph()

    sess=tf.Session()    
    #First let's load meta graph and restore weights
    saver = tf.train.import_meta_graph('checkpoints/animals.ckpt.meta')
    saver.restore(sess,tf.train.latest_checkpoint('checkpoints/'))


    # Now, let's access and create placeholders variables and
    # create feed-dict to feed new data

    graph = tf.get_default_graph()
    
    input_ = tf.placeholder(tf.float32, [None, 224, 224, 3])
    vgg = vgg16.Vgg16()
    vgg.build(input_)
    
    feed_dict = {input_: img}
    code = sess.run(vgg.relu6, feed_dict=feed_dict)
    
    inputs_ = graph.get_tensor_by_name('inputs:0')
    predicted = graph.get_tensor_by_name('op_predicted:0')


feed = {inputs_: code}
prediction = sess.run(predicted, feed_dict=feed).squeeze()
print(prediction)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/animals.ckpt
# E:\backend-test\Mqtt-Python\tensorflow_vgg\vgg16.npy
# npy file loaded
# build model started
# build model finished: 4s
# [0.0000000e+00 3.5400003e-13 3.9584790e-27 1.1758157e-27 1.0000000e+00]

# %%
image = io.imread(img_src)
io.imshow(image)
io.show()
# Out:
# D:\Anaconda\envs\dlnd\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
print(lb.classes_)
# Out:
# ['bird' 'cat' 'dog' 'fish' 'tiger']

# %%
plt.barh(np.arange(5), prediction)
_ = plt.yticks(np.arange(5), lb.classes_)

# %%
test_img_path = 'flower_photos/roses/12045735155_42547ce4e9_n.jpg'
test_img = imread(test_img_path)
plt.imshow(test_img)
# Out:
# D:\Anaconda\envs\dlnd\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0.
# Use ``matplotlib.pyplot.imread`` instead.

# %%
plt.imshow(test_img)
